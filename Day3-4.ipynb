# %% [markdown]
# # DAY 3

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("day3 data\\placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa  resume_score  placed
# 0           0    12         12.52       6
# 1           1    10         11.17       5
# 2           2    12         14.86       6
# 3           3    10         13.27       6
# 4           4    11         13.30       6

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 95          95    10         12.38       5
# 96          96    12         13.76       6
# 97          97    10         13.78       5
# 98          98    12         11.63       6
# 99          99    10         12.61       5

# %%
df.describe()
# Out:
#        Unnamed: 0        cgpa  resume_score      placed
# count  100.000000  100.000000    100.000000  100.000000
# mean    49.500000   10.470000     12.930500    5.500000
# std     29.011492    1.201472      0.979608    0.502519
# min      0.000000    9.000000     10.950000    5.000000
# 25%     24.750000    9.000000     12.190000    5.000000
# 50%     49.500000   10.000000     13.055000    5.500000
# 75%     74.250000   12.000000     13.640000    6.000000
# max     99.000000   13.000000     15.060000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    100 non-null    int64
#  1   cgpa          100 non-null    int64
#  2   resume_score  100 non-null    float64
#  3   placed        100 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 3.3 KB

# %%
top_left_corner = df.iloc[:4,:3]
top_left_corner
# Out:
#    Unnamed: 0  cgpa  resume_score
# 0           0    12         12.52
# 1           1    10         11.17
# 2           2    12         14.86
# 3           3    10         13.27

# %%
topleftcornerLoc = df.loc[1:3,["cgpa","placed"]]
topleftcornerLoc
# Out:
#    cgpa  placed
# 1    10       5
# 2    12       6
# 3    10       6

# %%
dtype = df.dtypes
dtype
# Out:
# Unnamed: 0        int64
# cgpa              int64
# resume_score    float64
# placed            int64
# dtype: object

# %%
df["cgpa"].dtypes
# Out:
# dtype('int64')

# %%
df.empty # to check if the dataframe is empty or not
# Out:
# False

# %%
df.isnull() # to check if there are any null values in the dataframe
# Out:
#     Unnamed: 0   cgpa  resume_score  placed
# 0        False  False         False   False
# 1        False  False         False   False
# 2        False  False         False   False
# 3        False  False         False   False
# 4        False  False         False   False
# ..         ...    ...           ...     ...
# 95       False  False         False   False
# 96       False  False         False   False
# 97       False  False         False   False
# 98       False  False         False   False
# 99       False  False         False   False
#
# [100 rows x 4 columns]

# %%
df.isnull().sum() # to check the number of null values in each column
# Out:
# Unnamed: 0      0
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna() # to drop the rows with null values
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 0            0    12         12.52       6
# 1            1    10         11.17       5
# 2            2    12         14.86       6
# 3            3    10         13.27       6
# 4            4    11         13.30       6
# ..         ...   ...           ...     ...
# 95          95    10         12.38       5
# 96          96    12         13.76       6
# 97          97    10         13.78       5
# 98          98    12         11.63       6
# 99          99    10         12.61       5
#
# [100 rows x 4 columns]

# %%
df.shape # to check the number of rows and columns in the dataframe
# Out:
# (100, 4)

# %%
df.size #row count * column count
# Out:
# 400

# %%
df.values #
# Out:
# array([[ 0.  , 12.  , 12.52,  6.  ],
#        [ 1.  , 10.  , 11.17,  5.  ],
#        [ 2.  , 12.  , 14.86,  6.  ],
#        [ 3.  , 10.  , 13.27,  6.  ],
#        [ 4.  , 11.  , 13.3 ,  6.  ],
#        [ 5.  , 12.  , 12.19,  6.  ],
#        [ 6.  ,  9.  , 13.09,  5.  ],
#        [ 7.  , 10.  , 12.29,  5.  ],
#        [ 8.  , 10.  , 12.71,  5.  ],
#        [ 9.  , 11.  , 13.12,  6.  ],
#        [10.  , 10.  , 12.35,  5.  ],
#        [11.  ,  9.  , 12.54,  5.  ],
#        [12.  , 10.  , 13.01,  5.  ],
#        [13.  , 12.  , 11.09,  6.  ],
#        [14.  , 11.  , 12.25,  6.  ],
#        [15.  , 12.  , 11.93,  6.  ],
#        [16.  , 12.  , 13.64,  6.  ],
#        [17.  , 11.  , 14.71,  6.  ],
#        [18.  ,  9.  , 11.88,  5.  ],
#        [19.  , 10.  , 14.11,  6.  ],
#        [20.  ,  9.  , 14.06,  5.  ],
#        [21.  , 10.  , 13.64,  5.  ],
#        [22.  , 10.  , 11.77,  5.  ],
#        [23.  , 10.  , 13.13,  5.  ],
#        [24.  , 12.  , 12.18,  6.  ],
# ...

# %%
df.ndim # to check the number of dimensions in the dataframe
# Out:
# 2

# %%
dfCopy = df.copy() # to create a copy of the dataframe

# %%
sortedByResume = df.sort_values(by = 'resume_score')
sortedByResume
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 94          94    12         10.95       6
# 87          87     9         11.05       5
# 13          13    12         11.09       6
# 41          41    12         11.15       6
# 1            1    10         11.17       5
# ..         ...   ...           ...     ...
# 17          17    11         14.71       6
# 38          38    10         14.72       5
# 65          65    10         14.75       5
# 2            2    12         14.86       6
# 69          69    12         15.06       6
#
# [100 rows x 4 columns]

# %%
indexSort = df.sort_index()
indexSort
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 0            0    12         12.52       6
# 1            1    10         11.17       5
# 2            2    12         14.86       6
# 3            3    10         13.27       6
# 4            4    11         13.30       6
# ..         ...   ...           ...     ...
# 95          95    10         12.38       5
# 96          96    12         13.76       6
# 97          97    10         13.78       5
# 98          98    12         11.63       6
# 99          99    10         12.61       5
#
# [100 rows x 4 columns]

# %%
df["cgpa"] = df["cgpa"].astype(int)
df["cgpa"].dtypes
# Out:
# dtype('int64')

# %%
df
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 0            0    12         12.52       6
# 1            1    10         11.17       5
# 2            2    12         14.86       6
# 3            3    10         13.27       6
# 4            4    11         13.30       6
# ..         ...   ...           ...     ...
# 95          95    10         12.38       5
# 96          96    12         13.76       6
# 97          97    10         13.78       5
# 98          98    12         11.63       6
# 99          99    10         12.61       5
#
# [100 rows x 4 columns]

# %%
df["cgpa"] = df["cgpa"].add(4)
df["resume_score"] = df["resume_score"].add(6)
df["placed"] = df["placed"].add(5)

# %%
df
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 0            0    16         18.52      11
# 1            1    14         17.17      10
# 2            2    16         20.86      11
# 3            3    14         19.27      11
# 4            4    15         19.30      11
# ..         ...   ...           ...     ...
# 95          95    14         18.38      10
# 96          96    16         19.76      11
# 97          97    14         19.78      10
# 98          98    16         17.63      11
# 99          99    14         18.61      10
#
# [100 rows x 4 columns]

# %%
filtered = df.filter(items = ["cgpa","placed"])
filtered.head()
# Out:
#    cgpa  placed
# 0    16      11
# 1    14      10
# 2    16      11
# 3    14      11
# 4    15      11

# %%
#2nd filtering method
filtered2 = df[["cgpa","placed"]]
filtered2.head()
# Out:
#    cgpa  placed
# 0    16      11
# 1    14      10
# 2    16      11
# 3    14      11
# 4    15      11

# %%
df.filter(items = [5,6],axis=0) #axis = 0 for rows and axis = 1 for columns
# Out:
#    Unnamed: 0  cgpa  resume_score  placed
# 5           5    16         18.19      11
# 6           6    13         19.09      10

# %%
df.filter(like='5',axis=0) # to filter the rows that contain '5' in their index
# Out:
#     Unnamed: 0  cgpa  resume_score  placed
# 5            5    16         18.19      11
# 15          15    16         17.93      11
# 25          25    15         17.68      11
# 35          35    16         19.48      11
# 45          45    16         17.44      11
# 50          50    16         18.74      11
# 51          51    14         19.39      10
# 52          52    13         19.50      10
# 53          53    14         19.16      10
# 54          54    13         19.18      10
# 55          55    14         18.87      11
# 56          56    14         18.43      10
# 57          57    14         19.21      10
# 58          58    14         19.37      10
# 59          59    13         19.57      10
# 65          65    14         20.75      10
# 75          75    14         19.94      11
# 85          85    14         17.46      10
# 95          95    14         18.38      10

# %%
dictionary = df.to_dict() # to convert the dataframe to a dictionary

# %%
q = df.to_string()

# %%
csv = df.to_csv("day3 data\\placement.csv") # to convert the dataframe to a csv file

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df.columns[0]
# Out:
# 'Unnamed: 0'

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0', 'cgpa', 'resume_score', 'placed']

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'cgpa', 'resume_score', 'placed'], dtype=object)

# %%
renamedDF = df.rename(columns={"cgpa":"updated_cgpa",
                               "resume_score":"semester_marks"})
renamedDF.columns
# Out:
# Index(['Unnamed: 0', 'updated_cgpa', 'semester_marks', 'placed'], dtype='object')

# %%
df['half'] = df['cgpa'].where(df['cgpa'] > 7,other=0) # to replace the values in the column 'updated_cgpa' that are greater than 7 with NaN

# %%
df
# Out:
#     Unnamed: 0  cgpa  resume_score  placed  half
# 0            0    16         18.52      11    16
# 1            1    14         17.17      10    14
# 2            2    16         20.86      11    16
# 3            3    14         19.27      11    14
# 4            4    15         19.30      11    15
# ..         ...   ...           ...     ...   ...
# 95          95    14         18.38      10    14
# 96          96    16         19.76      11    16
# 97          97    14         19.78      10    14
# 98          98    16         17.63      11    16
# 99          99    14         18.61      10    14
#
# [100 rows x 5 columns]

# %% [markdown]
# # EDA - EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Parts of EDA
#     1.Univariate Analysis -> Analysis on a single independednt col.
#     2.Bivariate Analysis -> on 2 cols.
#     3.Multivariate Analysis -> on more than 2 cols.

# %% [markdown]
# ### Datatypes
#     1.Numerical data: continuos data -> that can be categorized (AGE[years,months.days], height,weight)
#     2. Categorical Data : discrete data -> Total no. of employess, marital status,etc.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("day3 data\\titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ### 1. Unvariate Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
SurvivalCount=df['Survived'].value_counts()
SurvivalCount
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
PClassCount=df['Pclass'].value_counts()
PClassCount
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f' )
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie',autopct = '%.2f' )
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(x=df['Age'],)
plt.show()

# %% [markdown]
#  # Day 4

# %%
#Boxplot
#to find outliers


#1.Lower Fence
#2.25% of data
#3.IQR (INTER QUARTILE RANGE)(75-25%)
#4.75% of data
#5.Upper Fence

# x = 1,2,3,4,5
#mean = 3
# x = 1,2,3,4,5,100
#meaan = 19.166666666666668 #100 is an outlier and it is increasing the mean value drastically

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
tips = sns.load_dataset("tips")
#tips is already included in sns

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
# SCATTERPLOT (NUMERICAL COL - NUMERICAL COL)
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
